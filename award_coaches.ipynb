# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_column',None)
pd.set_option('display.max_row',None)

# %%
#loading the dataset
df=pd.read_csv("basketball_awards_coaches.csv")
df
# Out:
#     year    coachID                  award lgID note
# 0   1962  gallaha01  NBA Coach of the Year  NBA  NaN
# 1   1963  hannual01  NBA Coach of the Year  NBA  NaN
# 2   1964  auerbre01  NBA Coach of the Year  NBA  NaN
# 3   1965  schaydo01  NBA Coach of the Year  NBA  NaN
# 4   1966   kerrjo01  NBA Coach of the Year  NBA  NaN
# ..   ...        ...                    ...  ...  ...
# 56  2007  scottby01  NBA Coach of the Year  NBA  NaN
# 57  2008  brownmi02  NBA Coach of the Year  NBA  NaN
# 58  2009  brooksc01  NBA Coach of the Year  NBA  NaN
# 59  2010  thiboto01  NBA Coach of the Year  NBA  NaN
# 60  2011  popovgr01  NBA Coach of the Year  NBA  NaN
#
# [61 rows x 5 columns]

# %%
#data set info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     61 non-null     int64
#  1   coachID  61 non-null     object
#  2   award    61 non-null     object
#  3   lgID     61 non-null     object
#  4   note     4 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 2.5+ KB

# %%
#checking for duplicates
df_dup=df.duplicated()
df_dup_df=pd.DataFrame(df_dup,columns=['duplicate'])
df_dup_df
# Out:
#     duplicate
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False

# %%
#checking number of columns
df.columns
# Out:
# Index(['year', 'coachID', 'award', 'lgID', 'note'], dtype='object')

# %%
#renaming column lgID for cosistency and clarity
award=df.rename(columns={'lgID':'leagueID'})
award
# Out:
#     year    coachID                  award leagueID note
# 0   1962  gallaha01  NBA Coach of the Year      NBA  NaN
# 1   1963  hannual01  NBA Coach of the Year      NBA  NaN
# 2   1964  auerbre01  NBA Coach of the Year      NBA  NaN
# 3   1965  schaydo01  NBA Coach of the Year      NBA  NaN
# 4   1966   kerrjo01  NBA Coach of the Year      NBA  NaN
# 5   1967  cazzevi01  ABA Coach of the Year      ABA  NaN
# 6   1967  gueriri01  NBA Coach of the Year      NBA  NaN
# 7   1968  hannual01  ABA Coach of the Year      ABA  NaN
# 8   1968   shuege01  NBA Coach of the Year      NBA  NaN
# 9   1969  sharmbi01  ABA Coach of the Year      ABA  tie
# 10  1969  belmojo01  ABA Coach of the Year      ABA  tie
# 11  1969  holzmre01  NBA Coach of the Year      NBA  NaN
# 12  1970  biancal01  ABA Coach of the Year      ABA  NaN
# 13  1970  mottadi01  NBA Coach of the Year      NBA  NaN
# 14  1971  nissato01  ABA Coach of the Year      ABA  NaN
# ...

# %%
#checking for missing values
award_null=award.isnull().sum()
award_null_award=pd.DataFrame(award_null,columns=['missing values'])
award_null_award
# Out:
#           missing values
# year                   0
# coachID                0
# award                  0
# leagueID               0
# note                  57

# %%
#checking for percentage of missing value.
float_percentage = []
string_percentage = []
for key, values  in award_null.items():
    percent_missing=(values/60)*100
    string_percentage.append(str(percent_missing)+'%')
    float_percentage.append(percent_missing)
missing_null=pd.DataFrame(index=award_null.keys(),columns=['percentage null'])
missing_null['percentage null']=string_percentage
missing_null
# Out:
#          percentage null
# year                0.0%
# coachID             0.0%
# award               0.0%
# leagueID            0.0%
# note               95.0%

# %%
#confirming the data size
award.shape
# Out:
# (61, 5)

# %%
#droping nulls
award_drop=award.dropna()
award_drop
# Out:
#     year    coachID                  award leagueID note
# 9   1969  sharmbi01  ABA Coach of the Year      ABA  tie
# 10  1969  belmojo01  ABA Coach of the Year      ABA  tie
# 18  1973  mccarba01  ABA Coach of the Year      ABA  tie
# 19  1973  mullajo01  ABA Coach of the Year      ABA  tie

# %%
#checking for nulls after droping nulls
award_drop.shape
# Out:
# (4, 5)

# %% [markdown]
# inference
# It is seen clearly that if the null in note column is to be droped the entire data set would be gone as more than 95% of the note column is a null also some of the null values in the note column are neccessarily not applicable.
#
# (1) Hence instead of dropping the null values they will be replaced with not applicable.

# %%
#replace nulls in note column with not applicable
award['note']=award['note'].fillna('not applicable')
award
# Out:
#     year    coachID                  award leagueID            note
# 0   1962  gallaha01  NBA Coach of the Year      NBA  not applicable
# 1   1963  hannual01  NBA Coach of the Year      NBA  not applicable
# 2   1964  auerbre01  NBA Coach of the Year      NBA  not applicable
# 3   1965  schaydo01  NBA Coach of the Year      NBA  not applicable
# 4   1966   kerrjo01  NBA Coach of the Year      NBA  not applicable
# 5   1967  cazzevi01  ABA Coach of the Year      ABA  not applicable
# 6   1967  gueriri01  NBA Coach of the Year      NBA  not applicable
# 7   1968  hannual01  ABA Coach of the Year      ABA  not applicable
# 8   1968   shuege01  NBA Coach of the Year      NBA  not applicable
# 9   1969  sharmbi01  ABA Coach of the Year      ABA             tie
# 10  1969  belmojo01  ABA Coach of the Year      ABA             tie
# 11  1969  holzmre01  NBA Coach of the Year      NBA  not applicable
# 12  1970  biancal01  ABA Coach of the Year      ABA  not applicable
# ...

# %%
#checking for size after cleaning.
award.shape
# Out:
# (61, 5)

# %%
#checking for null values after cleaning.
award.isnull().any()
# Out:
# year        False
# coachID     False
# award       False
# leagueID    False
# note        False
# dtype: bool
