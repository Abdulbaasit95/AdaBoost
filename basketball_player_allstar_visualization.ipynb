# %% [markdown]
# ### BASKETBALL PLAYER ALLSTAR

# %%
#IMPORT REQUIRED LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# PARSE IN THE DATA
df = pd.read_csv('basketball_player_allstar.csv')

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %%
# CHECK THE SHAPE OF THE DATA
df.shape
# Out:
# (1609, 23)

# %% [markdown]
# ##### There are a total of 1609 observations and 23 features

# %%
#CHECK THE FIRST FIVE OBSERVATIONS
df.head()
# Out:
#    player_id     last_name first_name  season_id conference league_id  \
# 0  abdulka01  Abdul-Jabbar     Kareem       1978       West       NBA
# 1  abdulka01  Abdul-Jabbar     Kareem       1969       East       NBA
# 2  abdulka01  Abdul-Jabbar     Kareem       1988       West       NBA
# 3  abdulka01  Abdul-Jabbar     Kareem       1987       West       NBA
# 4  abdulka01  Abdul-Jabbar     Kareem       1986       West       NBA
#
#    games_played  minutes  points  o_rebounds  ...  steals  blocks  turnovers  \
# 0             1       28    11.0         NaN  ...     NaN     NaN        NaN
# 1             1       18    10.0         NaN  ...     NaN     NaN        NaN
# 2             1       13     4.0         NaN  ...     NaN     NaN        NaN
# 3             1       14    10.0         NaN  ...     NaN     NaN        NaN
# 4             1       27    10.0         NaN  ...     NaN     NaN        NaN
#
#    personal_fouls  fg_attempted  fg_made  ft_attempted  ft_made  \
# ...

# %%
# DISPLAY ADDITIONAL INFORMATION ABOUT THE DATA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1609 entries, 0 to 1608
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   player_id        1609 non-null   object
#  1   last_name        1609 non-null   object
#  2   first_name       1609 non-null   object
#  3   season_id        1609 non-null   int64
#  4   conference       1609 non-null   object
#  5   league_id        1609 non-null   object
#  6   games_played     1609 non-null   int64
#  7   minutes          1609 non-null   int64
#  8   points           1562 non-null   float64
#  9   o_rebounds       493 non-null    float64
#  10  d_rebounds       493 non-null    float64
#  11  rebounds         1562 non-null   float64
#  12  assists          1562 non-null   float64
#  13  steals           398 non-null    float64
#  14  blocks           398 non-null    float64
#  15  turnovers        493 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# player_id             0
# last_name             0
# first_name            0
# season_id             0
# conference            0
# league_id             0
# games_played          0
# minutes               0
# points               47
# o_rebounds         1116
# d_rebounds         1116
# rebounds             47
# assists              47
# steals             1211
# blocks             1211
# turnovers          1116
# personal_fouls     1069
# fg_attempted         47
# fg_made              47
# ft_attempted         47
# ft_made              47
# three_attempted    1069
# three_made         1043
# dtype: int64

# %% [markdown]
# ##### From the above, there are 15 columns with missing values
#
# But before dealing with the missing values, let's get the descriptive statistics of the dataset

# %%
# GETTING THE STATISTICAL DISTRIBUTION OF THE DATA
df.describe()
# Out:
#         season_id  games_played      minutes       points  o_rebounds  \
# count  1609.00000        1609.0  1609.000000  1562.000000  493.000000
# mean   1978.95463           1.0    23.103170    10.749680    1.567951
# std      16.20411           0.0    15.221598     6.962659    1.725569
# min    1950.00000           1.0     0.000000     0.000000    0.000000
# 25%    1967.00000           1.0    16.000000     6.000000    0.000000
# 50%    1976.00000           1.0    21.000000    10.000000    1.000000
# 75%    1992.00000           1.0    27.000000    15.000000    2.000000
# max    2009.00000           1.0    99.000000    42.000000   13.000000
#
#        d_rebounds     rebounds      assists      steals      blocks  \
# count  493.000000  1562.000000  1562.000000  398.000000  398.000000
# mean     3.129817     4.933419     2.510883    1.128141    0.459799
# std      2.599911     3.971961     2.632560    1.268158    0.864725
# ...

# %% [markdown]
# ##### From the descriptive statistics shown above, we can infer that the following columns have OUTLIERS (EXTREME VALUES):
#
# - 'o_rebounds'
# - 'd_rebounds'
# - 'rebounds'
# - 'assists'
# - 'turnovers'
# - 'personal_fouls'
# - 'fg_attempted'
# - 'fg_made'
# - 'ft_attempted'
# - 'ft_made'
# - 'three_attempted'
# - 'minutes'

# %% [markdown]
# ###### LET'S USE A BOX PLOT TO JUSTIFY THIS CLAIM

# %%
plt.figure(figsize = (20,15), tight_layout = True)
plt.subplot(4,3,1)
sns.boxplot(x = 'o_rebounds', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "O_REBOUNDS"')
plt.subplot(4,3,2)
sns.boxplot(x = 'd_rebounds', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "D_REBOUNDS"')
plt.subplot(4,3,3)
sns.boxplot(x = 'rebounds', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "REBOUNDS"')
plt.subplot(4,3,4)
sns.boxplot(x = 'assists', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "ASSISTS"')
plt.subplot(4,3,5)
sns.boxplot(x = 'turnovers', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "TURNOVERS"')
plt.subplot(4,3,6)
sns.boxplot(x = 'personal_fouls', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "PERSONAL_FOULS"')
plt.subplot(4,3,7)
sns.boxplot(x = 'fg_attempted', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "FG_ATTEMPTED"')
plt.subplot(4,3,8)
sns.boxplot(x = 'fg_made', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "FG_MADE"')
plt.subplot(4,3,9)
sns.boxplot(x = 'ft_attempted', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "FT_ATTEMPTED"')
plt.subplot(4,3,10)
sns.boxplot(x = 'ft_made', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "FT_MADE"')
plt.subplot(4,3,11)
sns.boxplot(x = 'three_attempted', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "THREE_ATTEMPTED"')
plt.subplot(4,3,12)
sns.boxplot(x = 'minutes', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "MINUTES"')
# Out:
# Text(0.5, 1.0, 'PLOT OF "LEAGUE_ID" AGAINST "MINUTES"')

# %% [markdown]
# ##### LET'S CHECK WHETHER THERE ARE DUPLICATED VALUES IN THE DATASET

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### AWESOME... THERE ARE NO DUPLICATED VALUES IN THE DATA
#
#
# ##### Let's now explore the 'GAMES_PLAYED' column and the 'LEAGUE_ID' column

# %%
df['league_id'].value_counts()
# Out:
# NBA    1406
# ABA     203
# Name: league_id, dtype: int64

# %%
sns.countplot(df['games_played'], hue = df['league_id'])
# Out:
# C:\Users\tajag\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='games_played', ylabel='count'>

# %% [markdown]
# ##### More games were played in the NBA league compared to the ABA league

# %% [markdown]
# ##### EXPLORING THE 'MINUTES' COLUMN

# %%
df['minutes'].value_counts()
# Out:
# 22    83
# 20    81
# 18    80
# 17    79
# 21    79
# 19    76
# 14    75
# 25    73
# 16    70
# 15    70
# 23    69
# 24    63
# 27    59
# 26    59
# 28    57
# 99    46
# 12    46
# 29    43
# 31    42
# 13    42
# 11    39
# 30    30
# 32    27
# 0     21
# 36    21
# 33    20
# 34    19
# 9     16
# 7     15
# 10    14
# 35    13
# 8     12
# 4     11
# 37    11
# 6      9
# 5      9
# 39     6
# 40     5
# 38     5
# 3      4
# 42     4
# 41     3
# 98     1
# 1      1
# 2      1
# Name: minutes, dtype: int64

# %%
sns.distplot(df['minutes'])
# Out:
# C:\Users\tajag\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='minutes', ylabel='Density'>

# %%
sns.boxplot(x = 'minutes', y = 'league_id', data = df)
plt.title('PLOT OF "LEAGUE_ID" AGAINST "MINUTES"')
# Out:
# Text(0.5, 1.0, 'PLOT OF "LEAGUE_ID" AGAINST "MINUTES"')

# %% [markdown]
# ##### From the above plots, it can be observed that the "Minutes" column had outlier values of 98 and 99 minutes in the NBA league. There are no such thing in the ABA league. Removing the outliers would make this column have a nearly perfect gaussian distribution.

# %% [markdown]
# ##### Create a new column 'Full Name' by concatenating the 'First name' and the 'Last name'

# %%
df['full_name'] = df['first_name'] + ' ' + df['last_name']

# %% [markdown]
# ##### EXPLORING THE POINTS COLUMN

# %%
df.groupby(['player_id','full_name'])['points'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# ervinju01  Julius Erving          321.0
# jordami01  Michael Jordan         262.0
# abdulka01  Kareem Abdul-Jabbar    251.0
# roberos01  Oscar Robertson        236.0
# pettibo01  Bob Pettit             224.0
#                                   ...
# gaborbi01  Billy Gabor              0.0
# imhofda01  Darrall Imhoff           0.0
# greenac01  A.C. Green               0.0
# johnsne01  Neil Johnson             0.0
# cheekma01  Maurcie Cheeks           0.0
# Name: points, Length: 462, dtype: float64

# %%
tot_point = df.groupby(['full_name'])['points'].sum()
plt.pie(x = tot_point.values, labels = tot_point.index, radius = 10)
# Out:
# ([<matplotlib.patches.Wedge at 0x18afab5dfa0>,
# ...
#  [Text(11.0, 0.0, 'A.C. Green'),
#   Text(10.999235838122678, 0.1296571531297878, 'Adrian Dantley'),
#   Text(10.99566825067471, 0.30867413416772826, 'Adrian Smith'),
#   Text(10.993623092473394, 0.37450140271531335, 'Al Horford'),
#   Text(10.986685245479155, 0.5410612874440754, 'Alex English'),
#   Text(10.976017147703999, 0.7259804221242785, 'Alex Groza'),
#   Text(10.971325547491581, 0.7937353028299496, 'Allan Houston'),
#   Text(10.945552998282208, 1.0931008927795005, 'Allen Iverson'),
#   Text(10.905254389817282, 1.4406341289067515, 'Alonzo Mourning'),
#   Text(10.89302512540647, 1.5303606167382047, 'Alvan Adams'),
#   Text(10.886633599507617, 1.5751853446727617, 'Alvin Robertson'),
#   Text(10.854591876174988, 1.7826483673669298, 'Amare Stoudemire'),
#   Text(10.824504128427549, 1.9570667780264879, 'Andrei Kirilenko'),
#   Text(10.815982092016172, 2.0036295528828396, 'Andrew Toney'),
# ...

# %% [markdown]
# ###### Julius Erving with player_id ERVINJU01 scored the highest cummulative number of points

# %% [markdown]
# ##### EXPLORING THE REBOUNDS COLUMN

# %%
df['rebounds'].unique()
# Out:
# array([ 8., 11.,  3.,  4.,  7.,  6., 13., 16.,  5., 10.,  0., 14.,  1.,
#         2.,  9., 15., 12., 22., 18., 17., 24., 25., 20., 19., 27., 26.,
#        21.])

# %%
df.groupby(['player_id','full_name'])['rebounds'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# chambwi01  Wilt Chamberlain       197.0
# pettibo01  Bob Pettit             178.0
# abdulka01  Kareem Abdul-Jabbar    139.0
# russebi01  Bill Russell           139.0
# duncati01  Tim Duncan             121.0
#                                   ...
# ratlith01  Theo Ratliff             0.0
# scolafr01  Fred Scolari             0.0
# buncela01  Larry Bunce              0.0
# rosede01   Derrick Rose             0.0
# hollili01  Lionel Hollins           0.0
# Name: rebounds, Length: 462, dtype: float64

# %% [markdown]
# ###### Wilt Chamberlain with player_id CHAMBWI01 had the highest cummulative number of rebounds

# %% [markdown]
# ##### EXPLORING THE O_REBOUNDS COLUMN

# %%
df['o_rebounds'].unique()
# Out:
# array([ 0.,  1.,  2.,  4.,  3.,  7.,  6.,  5.,  8., 13.])

# %%
df.groupby(['player_id','full_name'])['o_rebounds'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# duncati01  Tim Duncan          36.0
# garneke01  Kevin Garnett       24.0
# danieme01  Mel Daniels         20.0
# mariosh01  Shawn Marion        17.0
# isselda01  Dan Issel           17.0
#                                ...
# maravpe02  Pete Maravich        0.0
# mannida01  Danny Manning        0.0
# daviswa03  Walter Davis         0.0
# debusda01  Dave DeBusschere     0.0
# zasloma01  Max Zaslofsky        0.0
# Name: o_rebounds, Length: 462, dtype: float64

# %% [markdown]
# ###### Tim Duncan with player_id DUNCATI01 had the highest cummulative number of o_rebounds

# %% [markdown]
# ##### EXPLORING THE D_REBOUNDS COLUMN

# %%
df['d_rebounds'].unique()
# Out:
# array([ 0.,  2.,  5.,  1.,  4.,  6.,  8.,  3.,  9.,  7., 12., 11., 10.,
#        19.])

# %%
df.groupby(['player_id','full_name'])['d_rebounds'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# duncati01  Tim Duncan         85.0
# garneke01  Kevin Garnett      56.0
# danieme01  Mel Daniels        45.0
# mutomdi01  Dikembe Mutombo    41.0
# gilmoar01  Artis Gilmore      40.0
#                               ...
# mcguidi01  Dick McGuire        0.0
# mchalke01  Kevin McHale        0.0
# cousybo01  Bob Cousy           0.0
# meschto01  Tom Meschery        0.0
# zasloma01  Max Zaslofsky       0.0
# Name: d_rebounds, Length: 462, dtype: float64

# %% [markdown]
# ###### Tim Duncan with player_id DUNCATI01 had the highest cummulative number of d_rebounds

# %% [markdown]
# ##### EXPLORING THE PERSONAL_FOULS COLUMN

# %%
df['personal_fouls'].unique()
# Out:
# array([nan,  3.,  2.,  0.,  1.,  5.,  4.,  6.,  8.])

# %%
df['personal_fouls'].fillna(0, inplace = True)

# %% [markdown]
# I assumed that the entries with NaN values in the Personal_fouls column can be replaced with the value of zero.

# %%
df.groupby(['player_id','full_name'])['personal_fouls'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# bryanko01  Kobe Bryant        27.0
# gilmoar01  Artis Gilmore      27.0
# danieme01  Mel Daniels        20.0
# ervinju01  Julius Erving      20.0
# calvima01  Mack Calvin        16.0
#                               ...
# cheekma01  Maurice Cheeks      0.0
# cheniph01  Phil Chenier        0.0
# leverla01  Lafayette Lever     0.0
# leecl01    Clyde Lee           0.0
# zasloma01  Max Zaslofsky       0.0
# Name: personal_fouls, Length: 462, dtype: float64

# %% [markdown]
# ##### Kobe Bryant and Artis Gilmore both had a cummulative sum of 27 fouls each.

# %%
# REPLACING THE MISSING VALUES IN THE DATASET WITH ZERO
df.fillna(0, inplace = True)

# %% [markdown]
# ##### EXPLORING THE BLOCKS COLUMN

# %%
df['blocks'].unique()
# Out:
# array([0., 2., 1., 3., 5., 4.])

# %%
df.groupby(['player_id','full_name'])['blocks'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# garneke01  Kevin Garnett        9.0
# duncati01  Tim Duncan           8.0
# gervige01  George Gervin        8.0
# gilmoar01  Artis Gilmore        8.0
# oneash01   Shaquille O'Neal     8.0
#                                ...
# harribo02  Bob Harrison         0.0
# hardati01  Tim Hardaway         0.0
# hardaan01  Anfernee Hardaway    0.0
# hagancl01  Cliff Hagan          0.0
# zasloma01  Max Zaslofsky        0.0
# Name: blocks, Length: 462, dtype: float64

# %% [markdown]
# ###### Kelvin Garnett with player_id GARNEKE01 had the highest cummulative number of blocks

# %% [markdown]
# ##### EXPLORING THE STEALS COLUMN

# %%
df['steals'].unique()
# Out:
# array([0., 3., 1., 2., 4., 5., 6.])

# %%
df.groupby(['player_id','full_name'])['steals'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# bryanko01  Kobe Bryant        28.0
# kiddja01   Jason Kidd         22.0
# iversal01  Allen Iverson      21.0
# garneke01  Kevin Garnett      15.0
# jamesle01  LeBron James       14.0
#                               ...
# hightwa01  Wayne Hightower     0.0
# heinsto01  Tom Heinsohn        0.0
#            Tom Heinsohm        0.0
# hazzawa01  Walt Hazzard        0.0
# zasloma01  Max Zaslofsky       0.0
# Name: steals, Length: 462, dtype: float64

# %% [markdown]
# ###### Kobe Bryant with player_id BRYANKO01 had the highest cummulative number of steals.

# %% [markdown]
# ##### EXPLORING THE ASSISTS COLUMN

# %%
df['assists'].unique()
# Out:
# array([ 3.,  4.,  0.,  2.,  1.,  5.,  9.,  6.,  7.,  8., 11., 10., 13.,
#        19., 15., 22., 16., 14., 17.])

# %%
df.groupby(['player_id','full_name'])['assists'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# johnsma01  Magic Johnson       127.0
# thomais01  Isiah Thomas         97.0
# cousybo01  Bob Cousy            86.0
# roberos01  Oscar Robertson      81.0
# paytoga01  Gary Payton          73.0
#                                ...
# keyeju01   Julius Keye           0.0
# hillty01   Tyrone Hill           0.0
# vaughch01  Chico Vaughn          0.0
# abdursh01  Shareef A-Rahim       0.0
# kirilan01  Andrei Kirilenko      0.0
# Name: assists, Length: 462, dtype: float64

# %% [markdown]
# ###### Magic Johnson with player_id JOHNSMA01 had the highest cummulative number of assists.

# %% [markdown]
# ##### EXPLORING THE THREE_ATTEMPTED COLUMN

# %%
df['three_attempted'].unique()
# Out:
# array([ 0.,  1., 10.,  7.,  6.,  4.,  3.,  9., 11.,  2.,  8.,  5.])

# %%
df.groupby(['player_id','full_name'])['three_attempted'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# allenra02  Ray Allen          64.0
# bryanko01  Kobe Bryant        48.0
# jamesle01  LeBron James       40.0
# mcgratr01  Tracy McGrady      37.0
# piercpa01  Paul Pierce        25.0
#                               ...
# heinsto01  Tom Heinsohm        0.0
# hazzawa01  Walt Hazzard        0.0
# haywosp01  Spencer Haywood     0.0
# hayesel01  Elvin Hayes         0.0
# zasloma01  Max Zaslofsky       0.0
# Name: three_attempted, Length: 462, dtype: float64

# %% [markdown]
# ###### Ray Allen with player_id ALLENRA02 had the highest cummulative number of three_attempted.

# %% [markdown]
# ##### EXPLORING THE THREE_MADE COLUMN

# %%
df['three_made'].unique()
# Out:
# array([0., 1., 3., 5., 4., 2., 6.])

# %%
df.groupby(['player_id','full_name'])['three_made'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# allenra02  Ray Allen         20.0
# bryanko01  Kobe Bryant       17.0
# jamesle01  LeBron James      14.0
# mcgratr01  Tracy McGrady     13.0
# kiddja01   Jason Kidd        10.0
#                              ...
# hayesel01  Elvin Hayes        0.0
# hawkihe01  Hersey Hawkins     0.0
# hawkico01  Connie Hawkins     0.0
# havlijo01  John Havlicek      0.0
# zasloma01  Max Zaslofsky      0.0
# Name: three_made, Length: 462, dtype: float64

# %% [markdown]
# ###### Ray Allen with player_id ALLENRA02 had the highest cummulative number of three_made.

# %% [markdown]
# ##### EXPLORING THE TURNOVERS COLUMN

# %%
df['turnovers'].unique()
# Out:
# array([0., 1., 3., 2., 4., 7., 6., 5., 8.])

# %%
df.groupby(['player_id','full_name'])['turnovers'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# iversal01  Allen Iverson      38.0
# duncati01  Tim Duncan         31.0
# bryanko01  Kobe Bryant        30.0
# kiddja01   Jason Kidd         21.0
# garneke01  Kevin Garnett      20.0
#                               ...
# mashbja01  Jamal Mashburn      0.0
# martisl01  Slater Martin       0.0
# duckwke01  Kevin Duckworth     0.0
# dukeswa01  Walter Dukes        0.0
# zasloma01  Max Zaslofsky       0.0
# Name: turnovers, Length: 462, dtype: float64

# %% [markdown]
# ###### Allen Iverson with player_id IVERSAL01 had the highest cummulative number of turnovers.

# %% [markdown]
# ##### EXPLORING THE FG_ATTEMPTED COLUMN

# %%
df['fg_attempted'].unique()
# Out:
# array([12.,  8.,  6.,  9., 15., 10., 19., 17., 14., 16., 11.,  0.,  4.,
#        13., 22.,  7.,  5.,  2.,  1., 20., 27., 23., 18.,  3., 25., 24.,
#        26., 21.])

# %%
df.groupby(['player_id','full_name'])['fg_attempted'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# ervinju01  Julius Erving          248.0
# jordami01  Michael Jordan         233.0
# abdulka01  Kareem Abdul-Jabbar    213.0
# pettibo01  Bob Pettit             193.0
# bryanko01  Kobe Bryant            175.0
#                                   ...
# cebalce01  Cedric Ceballos          0.0
# cheekma01  Maurcie Cheeks           0.0
# ratlith01  Theo Ratliff             0.0
# eatonma01  Mark Eaton               0.0
# donalja01  James Donaldson          0.0
# Name: fg_attempted, Length: 462, dtype: float64

# %% [markdown]
# ###### Julius Erving with player_id ERVINJU01 had the highest cummulative number of fg_attempted.

# %% [markdown]
# ##### EXPLORING THE FG_MADE COLUMN

# %%
df['fg_made'].unique()
# Out:
# array([ 5.,  4.,  1.,  9., 11.,  6.,  8.,  3.,  7.,  0.,  2., 10., 13.,
#        16., 12., 17., 14., 15.])

# %%
df.groupby(['player_id','full_name'])['fg_made'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# ervinju01  Julius Erving          123.0
# jordami01  Michael Jordan         110.0
# abdulka01  Kareem Abdul-Jabbar    105.0
# bryanko01  Kobe Bryant             88.0
# roberos01  Oscar Robertson         88.0
#                                   ...
# masonan01  Anthony Mason            0.0
# johnsne01  Neil Johnson             0.0
# cheekma01  Maurcie Cheeks           0.0
# carrau01   Austin Carr              0.0
# gaborbi01  Billy Gabor              0.0
# Name: fg_made, Length: 462, dtype: float64

# %% [markdown]
# ###### Julius Erving with player_id ERVINJU01 had the highest cummulative number of fg_made.

# %% [markdown]
# ##### EXPLORING THE FT_ATTEMPTED COLUMN

# %%
df['ft_attempted'].unique()
# Out:
# array([ 2.,  4.,  3.,  6.,  0.,  5.,  1.,  8.,  9.,  7., 12., 11., 13.,
#        14., 10., 16., 15.])

# %%
df.groupby(['player_id','full_name'])['ft_attempted'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# roberos01  Oscar Robertson     98.0
# bayloel01  Elgin Baylor        98.0
# chambwi01  Wilt Chamberlain    94.0
# ervinju01  Julius Erving       82.0
# pettibo01  Bob Pettit          80.0
#                                ...
# johnsjo01  John Johnson         0.0
# ratlith01  Theo Ratliff         0.0
# reddmi01   Michael Redd         0.0
# davisan01  Antonio Davis        0.0
# ladnewe01  Wendell Ladner       0.0
# Name: ft_attempted, Length: 462, dtype: float64

# %% [markdown]
# ###### Oscar Robertson and Elgin Baylor both had the highest cummulative number of ft_attempted.

# %% [markdown]
# ##### EXPLORING THE FT_MADE COLUMN

# %%
df['ft_made'].unique()
# Out:
# array([ 1.,  2.,  3.,  5.,  4.,  0.,  7.,  8.,  6., 11.,  9., 12., 10.])

# %%
df.groupby(['player_id','full_name'])['ft_made'].sum().sort_values(ascending = False)
# Out:
# player_id  full_name
# bayloel01  Elgin Baylor        78.0
# ervinju01  Julius Erving       73.0
# roberos01  Oscar Robertson     70.0
# pettibo01  Bob Pettit          62.0
# chambwi01  Wilt Chamberlain    47.0
#                                ...
# cliftna01  Nat Clifton          0.0
# oneash11   Shaquille O'Neal     0.0
# paulch01   Chris Paul           0.0
# cheekma01  Maurcie Cheeks       0.0
# ladnewe01  Wendell Ladner       0.0
# Name: ft_made, Length: 462, dtype: float64

# %% [markdown]
# ###### Elgin Baylor with player_id BAYLOEL01 had the highest cummulative number of ft_made.

# %% [markdown]
# ## I DIDN'T VISUALIZE MOST OF THE INFERENCES BECAUSE OF TOO MANY UNIQUE VALUES IN THE PLAYER_ID COLUMN. THE PLOTS ARE TOO CHOKED
