# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df_teams = pd.read_csv('basketball_teams.csv')

# %%
df_teams.head()
# Out:
#    year lgID tmID franchID confID divID  rank  confRank playoff  \
# 0  1946  NBA  BOS      BOS    NaN    ED     5         0     NaN
# 1  1946  NBA  CHS      CHS    NaN    WD     1         0       F
# 2  1946  NBA  CLR      CLR    NaN    WD     3         0      R1
# 3  1946  NBA  DTF      DTF    NaN    WD     4         0     NaN
# 4  1946  NBA  NYK      NYK    NaN    ED     3         0      SF
#
#                name  ...  divWon  divLoss  pace  won  lost  games      min  \
# 0    Boston Celtics  ...      11       19     0   22    38     60  14500.0
# 1     Chicago Stags  ...      17        8     0   39    22     61  14840.0
# 2  Cleveland Rebels  ...      10       14     0   30    30     60  14600.0
# 3   Detroit Falcons  ...       8       16     0   20    40     60  14600.0
# 4   New York Knicks  ...      13       17     0   33    27     60  14575.0
#
#                          arena  attendance  bbtmID
# 0                Boston Garden       32767     BOS
# ...

# %%
df_teams.isnull().sum()
# Out:
# year             0
# lgID             0
# tmID             0
# franchID         0
# confID         472
# divID           38
# rank             0
# confRank         0
# playoff        635
# name             0
# o_fgm            0
# o_fga            0
# o_ftm            0
# o_fta            0
# o_3pm            0
# o_3pa            0
# o_oreb           0
# o_dreb           0
# o_reb            0
# o_asts           0
# o_pf             0
# o_stl            0
# o_to             0
# o_blk            0
# o_pts            0
# d_fgm            0
# d_fga            0
# d_ftm            0
# d_fta            0
# d_3pm            0
# d_3pa            0
# d_oreb           0
# d_dreb           0
# d_reb            0
# d_asts           0
# d_pf             0
# d_stl            0
# d_to             0
# d_blk            0
# d_pts            0
# o_tmRebound      0
# d_tmRebound      0
# homeWon          0
# homeLost         0
# awayWon          0
# awayLost         0
# neutWon          0
# ...

# %%
df_teams.tail()
# Out:
#       year lgID tmID franchID confID divID  rank  confRank playoff  \
# 1531  1937  NBL  KNK      KNK    NaN    WE     6         0     NaN
# 1532  1937  NBL  OSH      OSH    NaN    WE     1         0      LC
# 1533  1937  NBL  PGP      PGP    NaN    EA     3         0     NaN
# 1534  1937  NBL  WAR      CWH    NaN    EA     5         0     NaN
# 1535  1937  NBL  WHT      HAM    NaN    WE     2         0      CF
#
#                               name  ...  divWon  divLoss  pace  won  lost  \
# 1531    Kankakee Gallagher Trojans  ...       0        0     0    3    11
# 1532             Oshkosh All-Stars  ...       0        0     0   12     2
# 1533            Pittsburgh Pirates  ...       0        0     0    8     5
# 1534                  Warren Penns  ...       0        0     0    3     9
# 1535  Whiting Ciesar All-Americans  ...       0        0     0   12     3
#
#       games  min  arena  attendance  bbtmID
# 1531     14  NaN    NaN           0     KNK
# ...

# %%
df_teams.shape
# Out:
# (1536, 60)

# %%
df_teams_drop = df_teams.dropna(axis=1)
df_teams_drop
# Out:
#       year lgID tmID franchID  rank  confRank                          name  \
# 0     1946  NBA  BOS      BOS     5         0                Boston Celtics
# 1     1946  NBA  CHS      CHS     1         0                 Chicago Stags
# 2     1946  NBA  CLR      CLR     3         0              Cleveland Rebels
# 3     1946  NBA  DTF      DTF     4         0               Detroit Falcons
# 4     1946  NBA  NYK      NYK     3         0               New York Knicks
# ...    ...  ...  ...      ...   ...       ...                           ...
# 1531  1937  NBL  KNK      KNK     6         0    Kankakee Gallagher Trojans
# 1532  1937  NBL  OSH      OSH     1         0             Oshkosh All-Stars
# 1533  1937  NBL  PGP      PGP     3         0            Pittsburgh Pirates
# 1534  1937  NBL  WAR      CWH     5         0                  Warren Penns
# 1535  1937  NBL  WHT      HAM     2         0  Whiting Ciesar All-Americans
#
# ...

# %%
df_teams_drop.isnull().sum().sum()
# Out:
# 0
